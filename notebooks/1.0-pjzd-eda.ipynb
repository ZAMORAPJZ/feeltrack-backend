# %%
from IPython.display import display, HTML

def show_image(url, width=1600):
    display(HTML(f"<img src='{url}' width={width}>"))

show_image('https://i.imgur.com/XLD0c0o.png')
# Out:
# <img src='https://i.imgur.com/XLD0c0o.png' width=1600>

# %% [markdown]
# # 1. Problema a resolver
# El problema abordado es la falta de comprensión estructurada sobre cómo los usuarios perciben productos o servicios. Las empresas reciben miles de comentarios, pero no cuentan con herramientas efectivas para analizarlos emocionalmente.

# %% [markdown]
# ##  2. Diccionario de datos
# El dataset 'ComentarioTikTok' contiene información de **10,000 comentarios** del histórico naufragio. A continuación, se describen las variables disponibles:
#
# | Variable            | Tipo       | Descripción |
# |---------------------|------------|-------------|
# | `user`              | Object    | Nombre de usuario |
# | `user_id`           | int    | ID del usuario |
# | `text`              | object | Comentario realizado por el usuario |
# | `like`              | int  | Cantidad de likes en un comentario |
# | `reply_count`       | int    | Cantidad de respuestas en un comentario |
# | `timestamp`         | object  | Codigo de la fecha |
# | `fecha_legible`     | object  | fecha del comentario realizado |

# %% [markdown]
# ## 3. Exploración inicial
# Cargar el dataset desde Google Drive, se habilitan los permisos
# Ademas, se importa las librerias pandas para el analisis del dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Importamos liberias
import pandas as pd

# %%
# Lectura de archivo
ruta = '/content/drive/MyDrive/PROYECTO/COMENTARIOTIKTOK-SELECCION.csv'
df = pd.read_csv(ruta)

# %%
print(df.shape)
df.head()
# Out:
# (1769, 7)
#                   user              user_id  \
# 0             skyevil6  6903611670226437121
# 1                YWH 🐐  6977605408710394885
# 2            Joseca_08  6836139685942576134
# 3  Ronal Ramos Sanchez  6786196328880817157
# 4       ♡Lu!$ @LF○N$●♧  6980168612896048134
#
#                                                 text  likes  reply_count  \
# 0  Nadie va agradecer a Zambrano por ese gran pas...   4912           37
# 1  Alianza Lima y la U le ganaron al liverpool y ...   3477           37
# 2  Para mi sonne fue el sacrificado del partido. ...   3629           22
# 3  Zambrano fue un "crack " y es el tipo de jugad...   1235           10
# 4  hablan de quispe pero el pase para quispe de q...   1252           40
#
#     timestamp        fecha_legible
# 0  1728708544  2024-10-11 23:49:04
# 1  1728721058  2024-10-12 03:17:38
# 2  1728745821  2024-10-12 10:10:21
# 3  1728738245  2024-10-12 08:04:05
# 4  1728733689  2024-10-12 06:48:09

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1769 entries, 0 to 1768
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   user           1769 non-null   object
#  1   user_id        1769 non-null   int64
#  2   text           1769 non-null   object
#  3   likes          1769 non-null   int64
#  4   reply_count    1769 non-null   int64
#  5   timestamp      1769 non-null   int64
#  6   fecha_legible  1769 non-null   object
# dtypes: int64(4), object(3)
# memory usage: 96.9+ KB

# %% [markdown]
# ## 4. Limpieza de datos
#
#
# *   Traducción automática de comentarios al español
# *   Limpieza básica del texto
# *   Tokenización, lematización y limpieza de palabras vacías con spaCy
# *   Aplicar procesamiento NLP al texto limpio
# *   Eliminación columnas irrelevantes

# %% [markdown]
# # Instalación de librerías para procesamiento de texto
# En este paso se instalan las herramientas principales para el procesamiento de texto en lenguaje natural:
#
#
# *   spaCy: Para lematización, tokenización y análisis
# *   deep-translator: Para traducir los comentarios a español si están en otro idioma.

# %%
# !pip install -q spacy
# !python -m spacy download es_core_news_sm
# !python -m spacy download en_core_web_sm
# Out:
# Collecting es-core-news-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/es_core_news_sm-3.8.0/es_core_news_sm-3.8.0-py3-none-any.whl (12.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.9/12.9 MB 74.2 MB/s eta 0:00:00
# Installing collected packages: es-core-news-sm
# Successfully installed es-core-news-sm-3.8.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('es_core_news_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 65.2 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
# !pip install -q deep-translator
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 kB 835.7 kB/s eta 0:00:00

# %% [markdown]
# #4.1 Traducción automática de comentarios al español
# Esta función detecta automáticamente el idioma del texto y lo traduce al español utilizando Google Translate.

# %%
from deep_translator import GoogleTranslator

def traducir_a_espanol(texto):
    try:
        return GoogleTranslator(source='auto', target='es').translate(texto)
    except:
        return texto

# %%
# Traducir los comentarios al español
df['texto_es'] = df['text'].astype(str).apply(traducir_a_espanol)
df.head()
# Out:
#                   user              user_id  \
# 0             skyevil6  6903611670226437121
# 1                YWH 🐐  6977605408710394885
# 2            Joseca_08  6836139685942576134
# 3  Ronal Ramos Sanchez  6786196328880817157
# 4       ♡Lu!$ @LF○N$●♧  6980168612896048134
#
#                                                 text  likes  reply_count  \
# 0  Nadie va agradecer a Zambrano por ese gran pas...   4912           37
# 1  Alianza Lima y la U le ganaron al liverpool y ...   3477           37
# 2  Para mi sonne fue el sacrificado del partido. ...   3629           22
# 3  Zambrano fue un "crack " y es el tipo de jugad...   1235           10
# 4  hablan de quispe pero el pase para quispe de q...   1252           40
#
#     timestamp        fecha_legible  \
# 0  1728708544  2024-10-11 23:49:04
# 1  1728721058  2024-10-12 03:17:38
# 2  1728745821  2024-10-12 10:10:21
# 3  1728738245  2024-10-12 08:04:05
# 4  1728733689  2024-10-12 06:48:09
#
#                                             texto_es
# 0  Nadie va agradecer a Zambrano por ese gran pas...
# 1  Alianza Lima y la U le ganaron al liverpool y ...
# 2  Para mi sonne fue el sacrificado del partido. ...
# 3  Zambrano fue un "crack " y es el tipo de jugad...
# 4  hablan de quispe pero el pase para quispe de q...

# %% [markdown]
# Diccionario de Emojis

# %% [markdown]
# # 4.2 Limpieza básica del texto
#
#
# Se realiza una limpieza para eliminar elementos no útiles como URLs, menciones, hashtags, símbolos y se convierten los textos a minúsculas.Es un paso clave para dejar los comentarios listos para análisis.

# %%
import re

def limpiar_texto(texto):
    texto = re.sub(r"http\S+", "", texto)
    texto = re.sub(r"@\w+", "", texto)
    texto = re.sub(r"#\w+", "", texto)
    texto = re.sub(r"[^A-Za-zÁ-ÿñÑ\s]", "", texto)
    texto = texto.lower().strip()
    return texto

df['texto_limpio'] = df['texto_es'].astype(str).apply(limpiar_texto)

df
# Out:
#                           user              user_id  \
# 0                     skyevil6  6903611670226437121
# 1                        YWH 🐐  6977605408710394885
# 2                    Joseca_08  6836139685942576134
# 3          Ronal Ramos Sanchez  6786196328880817157
# 4               ♡Lu!$ @LF○N$●♧  6980168612896048134
# ...                        ...                  ...
# 1764         DADDY.JARA the_💛🌽  7190494677957837829
# 1765                noriegaa_6  6659074731578802181
# 1766  pasión x la bicolor 🇵🇪⚽💪  7105726994259657734
# 1767                   usuario  6885896340833780737
# 1768           🖤JHUNIOR_ C-P🖤🍻  7301897489353966597
#
#                                                    text  likes  reply_count  \
# 0     Nadie va agradecer a Zambrano por ese gran pas...   4912           37
# 1     Alianza Lima y la U le ganaron al liverpool y ...   3477           37
# 2     Para mi sonne fue el sacrificado del partido. ...   3629           22
# 3     Zambrano fue un "crack " y es el tipo de jugad...   1235           10
# 4     hablan de quispe pero el pase para quispe de q...   1252           40
# ...                                                 ...    ...          ...
# 1764                                      era hoy Ramón      0            0
# 1765                                               ❤️❤️      0            0
# 1766                        la casa se respeta 💪🇵🇪🇵🇪🇵🇪😭      0            0
# 1767                                      era hoy ramon      0            0
# 1768                                              vamos      0            0
#
#        timestamp        fecha_legible  \
# 0     1728708544  2024-10-11 23:49:04
# 1     1728721058  2024-10-12 03:17:38
# 2     1728745821  2024-10-12 10:10:21
# 3     1728738245  2024-10-12 08:04:05
# 4     1728733689  2024-10-12 06:48:09
# ...          ...                  ...
# 1764  1728708231  2024-10-11 23:43:51
# 1765  1728707867  2024-10-11 23:37:47
# 1766  1728707828  2024-10-11 23:37:08
# 1767  1728707349  2024-10-11 23:29:09
# 1768  1728706516  2024-10-11 23:15:16
#
#                                                texto_es  \
# 0     Nadie va agradecer a Zambrano por ese gran pas...
# 1     Alianza Lima y la U le ganaron al liverpool y ...
# 2     Para mi sonne fue el sacrificado del partido. ...
# 3     Zambrano fue un "crack " y es el tipo de jugad...
# 4     hablan de quispe pero el pase para quispe de q...
# ...                                                 ...
# 1764                                      era hoy Ramón
# 1765                                               None
# 1766                        la casa se respeta 💪🇵🇪🇵🇪🇵🇪😭
# 1767                                      era hoy ramon
# 1768                                              vamos
#
#                                            texto_limpio
# 0     nadie va agradecer a zambrano por ese gran pas...
# 1     alianza lima y la u le ganaron al liverpool y ...
# 2     para mi sonne fue el sacrificado del partido j...
# 3     zambrano fue un crack  y es el tipo de jugador...
# 4     hablan de quispe pero el pase para quispe de q...
# ...                                                 ...
# 1764                                      era hoy ramón
# 1765                                               none
# 1766                                 la casa se respeta
# 1767                                      era hoy ramon
# 1768                                              vamos
#
# [1769 rows x 9 columns]

# %% [markdown]
# # 4.3 Tokenización, lematización y limpieza de palabras vacías con spaCy
#
# spaCy se utiliza para descomponer el texto en palabras significativas (tokens), eliminar palabras vacías (stopwords) y obtener la forma base (lema) de cada palabra.

# %%
import spacy

nlp_es = spacy.load("es_core_news_sm")

def procesar_con_spacy(texto, nlp_model):
    doc = nlp_model(texto)
    tokens_limpios = [
        token.lemma_ for token in doc
        if not token.is_stop and not token.is_punct and len(token.text) > 2
    ]
    return " ".join(tokens_limpios)

# %% [markdown]
# # 4.4 Aplicar procesamiento NLP al texto limpio
# Ahora se aplica spaCy al texto ya limpio para obtener una versión optimizada del contenido textual.

# %%
df['texto_procesado'] = df['texto_limpio'].apply(lambda x: procesar_con_spacy(x, nlp_es))

df
# Out:
#                           user              user_id  \
# 0                     skyevil6  6903611670226437121
# 1                        YWH 🐐  6977605408710394885
# 2                    Joseca_08  6836139685942576134
# 3          Ronal Ramos Sanchez  6786196328880817157
# 4               ♡Lu!$ @LF○N$●♧  6980168612896048134
# ...                        ...                  ...
# 1764         DADDY.JARA the_💛🌽  7190494677957837829
# 1765                noriegaa_6  6659074731578802181
# 1766  pasión x la bicolor 🇵🇪⚽💪  7105726994259657734
# 1767                   usuario  6885896340833780737
# 1768           🖤JHUNIOR_ C-P🖤🍻  7301897489353966597
#
#                                                    text  likes  reply_count  \
# 0     Nadie va agradecer a Zambrano por ese gran pas...   4912           37
# 1     Alianza Lima y la U le ganaron al liverpool y ...   3477           37
# 2     Para mi sonne fue el sacrificado del partido. ...   3629           22
# 3     Zambrano fue un "crack " y es el tipo de jugad...   1235           10
# 4     hablan de quispe pero el pase para quispe de q...   1252           40
# ...                                                 ...    ...          ...
# 1764                                      era hoy Ramón      0            0
# 1765                                               ❤️❤️      0            0
# 1766                        la casa se respeta 💪🇵🇪🇵🇪🇵🇪😭      0            0
# 1767                                      era hoy ramon      0            0
# 1768                                              vamos      0            0
#
#        timestamp        fecha_legible  \
# 0     1728708544  2024-10-11 23:49:04
# 1     1728721058  2024-10-12 03:17:38
# 2     1728745821  2024-10-12 10:10:21
# 3     1728738245  2024-10-12 08:04:05
# 4     1728733689  2024-10-12 06:48:09
# ...          ...                  ...
# 1764  1728708231  2024-10-11 23:43:51
# 1765  1728707867  2024-10-11 23:37:47
# 1766  1728707828  2024-10-11 23:37:08
# 1767  1728707349  2024-10-11 23:29:09
# 1768  1728706516  2024-10-11 23:15:16
#
#                                                texto_es  \
# 0     Nadie va agradecer a Zambrano por ese gran pas...
# 1     Alianza Lima y la U le ganaron al liverpool y ...
# 2     Para mi sonne fue el sacrificado del partido. ...
# 3     Zambrano fue un "crack " y es el tipo de jugad...
# 4     hablan de quispe pero el pase para quispe de q...
# ...                                                 ...
# 1764                                      era hoy Ramón
# 1765                                               None
# 1766                        la casa se respeta 💪🇵🇪🇵🇪🇵🇪😭
# 1767                                      era hoy ramon
# 1768                                              vamos
#
#                                            texto_limpio  \
# 0     nadie va agradecer a zambrano por ese gran pas...
# 1     alianza lima y la u le ganaron al liverpool y ...
# 2     para mi sonne fue el sacrificado del partido j...
# 3     zambrano fue un crack  y es el tipo de jugador...
# 4     hablan de quispe pero el pase para quispe de q...
# ...                                                 ...
# 1764                                      era hoy ramón
# 1765                                               none
# 1766                                 la casa se respeta
# 1767                                      era hoy ramon
# 1768                                              vamos
#
#                                         texto_procesado
# 0     agradecer zambrano pase quispe centrar araujo ...
# 1              alianza lima ganar liverpool real madrid
# 2     sonne sacrificado partido jugar lateral centra...
# 3               zambrano crack tipo jugador hacer falta
# 4     quispe pase quispe  león zambrano pase pie quispe
# ...                                                 ...
# 1764                                              ramón
# 1765                                               none
# 1766                                      casa respetar
# 1767                                              ramon
# 1768
#
# [1769 rows x 10 columns]

# %% [markdown]
# # 4.5 Eliminación columnas irrelevantes
# Para facilitar el análisis posterior, se eliminan columnas que no aportan valor directo al análisis textual.

# %%
columnas_a_eliminar = ['user', 'user_id', 'timestamp', 'text']
df.drop(columns=columnas_a_eliminar, inplace=True, errors='ignore')

df
# Out:
#       likes  reply_count        fecha_legible  \
# 0      4912           37  2024-10-11 23:49:04
# 1      3477           37  2024-10-12 03:17:38
# 2      3629           22  2024-10-12 10:10:21
# 3      1235           10  2024-10-12 08:04:05
# 4      1252           40  2024-10-12 06:48:09
# ...     ...          ...                  ...
# 1764      0            0  2024-10-11 23:43:51
# 1765      0            0  2024-10-11 23:37:47
# 1766      0            0  2024-10-11 23:37:08
# 1767      0            0  2024-10-11 23:29:09
# 1768      0            0  2024-10-11 23:15:16
#
#                                                texto_es  \
# 0     Nadie va agradecer a Zambrano por ese gran pas...
# 1     Alianza Lima y la U le ganaron al liverpool y ...
# 2     Para mi sonne fue el sacrificado del partido. ...
# 3     Zambrano fue un "crack " y es el tipo de jugad...
# 4     hablan de quispe pero el pase para quispe de q...
# ...                                                 ...
# 1764                                      era hoy Ramón
# 1765                                               None
# 1766                        la casa se respeta 💪🇵🇪🇵🇪🇵🇪😭
# 1767                                      era hoy ramon
# 1768                                              vamos
#
#                                            texto_limpio  \
# 0     nadie va agradecer a zambrano por ese gran pas...
# 1     alianza lima y la u le ganaron al liverpool y ...
# 2     para mi sonne fue el sacrificado del partido j...
# 3     zambrano fue un crack  y es el tipo de jugador...
# 4     hablan de quispe pero el pase para quispe de q...
# ...                                                 ...
# 1764                                      era hoy ramón
# 1765                                               none
# 1766                                 la casa se respeta
# 1767                                      era hoy ramon
# 1768                                              vamos
#
#                                         texto_procesado
# 0     agradecer zambrano pase quispe centrar araujo ...
# 1              alianza lima ganar liverpool real madrid
# 2     sonne sacrificado partido jugar lateral centra...
# 3               zambrano crack tipo jugador hacer falta
# 4     quispe pase quispe  león zambrano pase pie quispe
# ...                                                 ...
# 1764                                              ramón
# 1765                                               none
# 1766                                      casa respetar
# 1767                                              ramon
# 1768
#
# [1769 rows x 6 columns]

# %% [markdown]
# # Visualización del dataset
#
# Finalmente se muestra una muestra aleatoria de los comentarios ya procesados, junto con su número de likes y respuestas.

# %%
df[['texto_procesado', 'likes', 'reply_count']].sample(20)
# Out:
#                                         texto_procesado  likes  reply_count
# 1325                                                         0            0
# 360                                                none      0            0
# 41                          guerrero carrillo advinculo     51            7
# 511                                          buenasoooo      0            0
# 1748                                               none      0            0
# 1039                          jugador tirado obtruccoon      0            0
# 297   perú clasificado gritar gol mundial porq tierr...      1            0
# 909           aguante peru cerrar boca uruguayo preciar      0            0
# 169                               suelo despareceír gol      2            0
# 1764                                              ramón      0            0
# 1752                                             bonito      0            0
# 1747                                  suponer gritaaaar      0            0
# 1649                 fosati abrir entendido joven jugar      0            0
# 1058  concentrado muchacho brasil jugador humano vic...      0            0
# 1673                                 gollllllllll punto      0            0
# 1513                                gracia alegría perú      0            0
# 1338                                               none      0            0
# 844   sensación pase zambranosentí parar él centrocm...      0            0
# 336                                           perú aajo      1            0
# 503                                                none      0            0

# %% [markdown]
# # 4.6 Eliminación de textos vacíos
# Aunque ya se han limpiado los textos, es posible que queden valores "nulos disfrazados" como cadenas vacías, espacios o valores mal parseados.

# %%
# Reemplazar textos no informativos con NaN de forma segura
df['texto_procesado'] = df['texto_procesado'].replace(['', ' ', 'nan', 'None', 'none', None], pd.NA)

# Eliminar filas con texto procesado vacío o no válido
df.dropna(subset=['texto_procesado'], inplace=True)

# Reiniciar índice después de limpiar
df.reset_index(drop=True, inplace=True)

# %%
df[['texto_procesado', 'likes', 'reply_count']].sample(20)
# Out:
#                                         texto_procesado  likes  reply_count
# 1088                             decir hablar franz gol      0            0
# 786                     sorry conche medre francés fino      0            0
# 43            fútbol peruano elegancia máximo explendor     70            1
# 75                                 sufra tranquilo doma      0            1
# 577                                  sonne míralo grito      0            0
# 1269                                        ganar paolo      0            0
# 820                                           peru meze      0            0
# 797                                brasil venir goleada      0            0
# 420                     trío perfecto gol impresionante      0            1
# 1347                       merecer peruano levantars yo      0            0
# 964   ganar muchacho perú cajo farfán pizarro paolo etc      0            0
# 952   terminar festejar gol abraham seguia tirado ar...      0            0
# 932   cambio generacional resultado entender selecci...      0            0
# 322                    gracias perú colombiano entender      1            0
# 185                                       desfoguir gol      2            0
# 528                   movimiento quispe clave mencionar      0            0
# 1232            ilógico knleganemosnpor equipo defender      0            0
# 645                         terrible pase leon zambrano      0            0
# 1012            valerar sudar camiseta equipo reconocer      0            0
# 1081                            jugador uruguay abraham      0            0

# %% [markdown]
# Eliminamos las columnas temporales

# %%
columnas_a_eliminar = ['texto_es', 'texto_limpio']
df.drop(columns=columnas_a_eliminar, inplace=True, errors='ignore')


print(df.shape)
df
# Out:
# (1132, 4)
#       likes  reply_count        fecha_legible  \
# 0      4912           37  2024-10-11 23:49:04
# 1      3477           37  2024-10-12 03:17:38
# 2      3629           22  2024-10-12 10:10:21
# 3      1235           10  2024-10-12 08:04:05
# 4      1252           40  2024-10-12 06:48:09
# ...     ...          ...                  ...
# 1127      0            0  2024-10-12 00:02:54
# 1128      0            0  2024-10-11 23:58:13
# 1129      0            0  2024-10-11 23:50:33
# 1130      0            0  2024-10-11 23:46:08
# 1131      0            0  2024-10-11 23:37:08
#
#                                         texto_procesado
# 0     agradecer zambrano pase quispe centrar araujo ...
# 1              alianza lima ganar liverpool real madrid
# 2     sonne sacrificado partido jugar lateral centra...
# 3               zambrano crack tipo jugador hacer falta
# 4     quispe pase quispe  león zambrano pase pie quispe
# ...                                                 ...
# 1127                                    preocupar abran
# 1128                                goooolllll ptmreeee
# 1129            ganar muchacho crecimiento sed victoria
# 1130  hermoso gracias equipo realmente partido sólid...
# 1131                                      casa respetar
#
# [1132 rows x 4 columns]
